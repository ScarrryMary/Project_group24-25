# %% [markdown]
# <a href="https://colab.research.google.com/github/ScarrryMary/Project_group24-25/blob/main/HW_neural_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание: "Чихуахуа или маффин? Классификация изображений с помощью нейросети"
#
# Твоя задача — научить нейросеть не позориться перед друзьями и отличать собачку от кекса, а то получишь чихуа маффини вместо баллерины капучино.
#
# Обучить нейронную сеть на Python, которая сможет отличать изображения собак породы чихуахуа от маффинов.
#
# ### Что надо сделать (нормальным языком):
# - Скачать датасет - https://www.kaggle.com/datasets/samuelcortinhas/muffin-vs-chihuahua-image-classification.
#
# - Запилить CNN (или нет) на Python, которая не будет путать еду и питомцев (иначе "это провал, как паста аль денте в микроволновке").
#
# - Доказать, что модель не "рофлит" — accuracy >85%, иначе "это не AI, а randomino calamardo".
#
# - Разделить данные на тренировочный и тестовый наборы.
#
# - Провести предобработку: изменение размера, нормализацию и т. д.
#
# Построение модели:
#
# - Использовать библиотеки tensorflow и keras.
#
# - Добавить слои: сверточные (Conv2D), пулинга (MaxPooling2D), полносвязные (Dense) и др.
#
# - Выбрать функцию активации (например, ReLU для скрытых слоёв и sigmoid/softmax для выходного).
#
# Обучение и оценка:
#
# - Обучить модель на тренировочных данных, используя model.fit().
#
# - Оценить качество на тестовом наборе с помощью метрик (accuracy, confusion_matrix).
#
# - Визуализировать результаты (графики точности и потерь).

# %% [markdown]
# ![muffin-meme2.jpg](data:image/jpeg;base64,...)
