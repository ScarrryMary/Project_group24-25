# %% [markdown]
# <a href="https://colab.research.google.com/github/ScarrryMary/Project_group24-25/blob/main/Seminar_1_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![мем10.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # VPython

# %% [markdown]
# БОЛЬШЕ ИНФОРМАЦИИ: https://matter-interactions.trinket.io/00_welcome_to_vpython#/welcome-to-vpython/getting-started
#
# https://www.glowscript.org/#/user/GlowScriptDemos/folder/Examples/

# %%
import vpython as vp

# %% [markdown]
# ### Simple examples
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/MakingGraphs
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/Collision-Detection
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/BounceAnimation
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/buttons-sliders
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/make-globe
#
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/textures
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/surface-plot
#
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/LaTeX
#
# https://www.glowscript.org/#/user/wlane/folder/VPythonForBeginners/program/make-grid

# %% [markdown]
# ## I) Force function

# %%
scene.title = "Modeling the motion of planets with the gravitational force"
scene.height = 600
scene.width = 800

e_graph = gcurve(color=color.blue)
def gforce(p1,p2):
    # Calculate the gravitational force exerted on p1 by p2.
    G = 1 # Change to 6.67e-11 to use real-world values.
    # Calculate distance vector between p1 and p2.
    r_vec = p1.pos-p2.pos
    # Calculate magnitude of distance vector.
    r_mag = mag(r_vec)
    # Calcualte unit vector of distance vector.
    r_hat = r_vec/r_mag
    # Calculate force magnitude.
    force_mag = G*p1.mass*p2.mass/r_mag**2
    # Calculate force vector.
    force_vec = -force_mag*r_hat

    return force_vec

star = sphere( pos=vector(0,0,0), radius=0.2, color=color.yellow,
               mass = 2.0*1000, momentum=vector(0,0,0), make_trail=True )
planet = sphere( pos=vector(1,0,0), radius=0.05, color=color.blue,
               mass = 1, momentum=vector(0,30,0), make_trail=True )

dt = 0.0001
t = 0
while (True):
    rate(100)

    # Calculate forces.
    star.force = gforce(star,planet)
    planet.force = gforce(planet,star)
    # Update momenta.
    star.momentum = star.momentum + star.force*dt
    planet.momentum = planet.momentum + planet.force*dt
    # Update positions.
    star.pos = star.pos + star.momentum/star.mass*dt
    planet.pos = planet.pos + planet.momentum/planet.mass*dt
    t = t + dt

# %% [markdown]
#  https://www.glowscript.org/#/user/pechenko089/folder/MyPrograms/program/solarsystem

# %% [markdown]
# ## II) Multiple Planets

# %% [markdown]
# https://www.glowscript.org/#/user/pechenko089/folder/MyPrograms/program/solar2/edit

# %% [markdown]
# ## III) Comets and Energy

# %% [markdown]
# https://www.glowscript.org/#/user/pechenko089/folder/MyPrograms/program/solar3

# %% [markdown]
# ## IV) Conservation of Energy

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/solar-system-energy

# %% [markdown]
# ## V) Crossing Orbits (Neptune and Pluto)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/solar-system-crossing-orbits

# %% [markdown]
# ## VI) Asteroid Belt (with random numbers)

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/Solar-System-asteroids/edit

# %% [markdown]
# ## Double star

# %% [markdown]
# https://www.glowscript.org/#/user/GlowScriptDemos/folder/Examples/program/BinaryStar-VPython

# %% [markdown]
# ## Potential energy motion

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/AAPT-visual/program/potential-energy-motion

# %% [markdown]
# ## Pi from collisions

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/Pi-from-Collisions

# %% [markdown]
# ## Random walk

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/RandomWalkIn3D

# %% [markdown]
# ## Lattice

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/atoms-array

# %% [markdown]
# ## Solid

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/solid

# %% [markdown]
# https://www.glowscript.org/#/user/GlowScriptDemos/folder/Examples/program/AtomicSolid-VPython

# %% [markdown]
# ## Polarization

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Let'sCodePhysics/program/polarization

# %% [markdown]
# ## Electron in light

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Modern-Physics/program/classical-electron-in-light

# %% [markdown]
# ## Water flow

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Physicsin3D/program/water-flow

# %% [markdown]
# ## Dipole vector field

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Physicsin3D/program/dipole-vector-field

# %% [markdown]
# ## Integration

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/Numerical-Integration-for-Beginners/program/integration-slider
#
# https://www.glowscript.org/#/user/wlane/folder/Numerical-Integration-for-Beginners/program/integration-slider-2d
#
# https://www.glowscript.org/#/user/wlane/folder/Numerical-Integration-for-Beginners/program/integration-slider-sphere

# %% [markdown]
# ## Rolling

# %% [markdown]
# https://www.glowscript.org/#/user/wlane/folder/PHYS151/program/rolling
#
# https://www.glowscript.org/#/user/wlane/folder/PHYS151/program/hypocycloid

# %% [markdown]
# ## Dipole electric field

# %% [markdown]
# https://www.glowscript.org/#/user/GlowScriptDemos/folder/Examples/program/DipoleElectricField

# %% [markdown]
# https://www.glowscript.org/#/user/GlowScriptDemos/folder/Examples/program/DoublePendulum-VPython

# %% [markdown]
# ## Rug

# %% [markdown]
# https://www.glowscript.org/#/user/GlowScriptDemos/folder/Examples/program/Rug
