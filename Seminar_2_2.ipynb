# %% [markdown]
# <a href="https://colab.research.google.com/github/ScarrryMary/Project_group24-25/blob/main/Seminar_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![5cd53567de23267d6c0af169b3b8d107.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Асимптотика алгоритмов (потребление ресурсов)

# %% [markdown]
# В асимптотическом анализе мы оцениваем производительность алгоритма с точки зрения размера входных данных (мы не измеряем фактическое время выполнения). Мы вычисляем порядок роста времени (или пространства), затраченного алгоритмом с точки зрения размера входных данных. Например, линейный поиск растет линейно, а двоичный поиск растет логарифмически с точки зрения размера входных данных.

# %% [markdown]
# **Примеры с анализом их сложности**:
# 1. Алгоритм линейного поиска:

# %%
# Linearly search target in arr.
# If target is present, return the index;
# otherwise, return -1
def search(arr, x):
    for i in range(len(arr)):
        if arr[i] == x:
            return i
    return -1

if __name__ == '__main__':
    arr = [1, 10, 30, 15]
    x = 30
    print(search(arr, x))

# %% [markdown]
# * Лучший случай: Постоянное время, независимо от размера входных данных. Это будет иметь место, если элемент для поиска находится в первом индексе указанного списка. Таким образом, количество сравнений в этом случае равно 1.
# * Средний случай: Линейное время. Это будет иметь место, если элемент для поиска находится в среднем индексе (при среднем поиске) указанного списка.
# * Худший случай: Элемент для поиска отсутствует в списке.
#
#
# 2.**Специальная сумма массива**:
# в этом примере мы возьмем массив длины (n) и рассмотрим следующие случаи:
#
# * Если (n) четное, то наш вывод будет равен 0.
# * Если (n) нечетно, то наш вывод будет представлять собой сумму элементов массива.
#
# Ниже представлена ​​реализация данной задачи:

# %%
def getSum(arr1):
    n = len(arr1)
    if n % 2 == 0:  # (n) is even
        return 0

    sum = 0
    for i in range(n):
        sum += arr1[i]
    return sum  # (n) is odd

if __name__ == '__main__':
    # Declaring two lists, one with an odd length
    # and the other with an even length
    arr1 = [1, 2, 3, 4]
    arr2 = [1, 2, 3, 4, 5]
    print(getSum(arr1))
    print(getSum(arr2))

# %% [markdown]
# ### Как анализировать циклы для анализа сложности алгоритмов
#
# Вот общие шаги по анализу циклов для анализа сложности:
#
# * Определить количество итераций цикла. Обычно это делается путем анализа переменных управления циклом и условия завершения цикла.
#
# * Определите количество операций, выполняемых в каждой итерации цикла. Это может включать как арифметические операции, так и операции доступа к данным, такие как доступ к массиву или доступ к памяти.
#
# * Выразите общее количество операций, выполненных циклом, как функцию размера входных данных. Это может включать использование математических выражений или нахождение выражения в замкнутой форме для количества операций, выполненных циклом.
#
# * Определите порядок роста выражения для числа операций, выполняемых циклом. Это можно сделать, используя такие методы, как нотация big O или найдя доминирующий член и игнорируя члены низшего порядка.

# %% [markdown]
# ### Постоянная временная сложность $O(1)$:
# Временная сложность функции (или набора операторов) считается равной O(1), если она не содержит циклов, рекурсий и вызовов других функций с непостоянным временем выполнения. То есть набор нерекурсивных и нециклических операторов.
#
# В информатике O(1) относится к постоянной временной сложности, что означает, что время выполнения алгоритма остается постоянным и не зависит от размера входных данных. Это означает, что время выполнения алгоритма O(1) всегда будет занимать одинаковое количество времени независимо от размера входных данных. Примером алгоритма O(1) является доступ к элементу массива с использованием индекса.
#
# **Пример**:
#
# * Функция swap() имеет временную сложность O(1).
#
# * Цикл или рекурсия, которая выполняется постоянное число раз, также считается O(1). Например, следующий цикл — O(1).

# %% [markdown]
# Анализ временной сложности:
#
# * Лучший случай: порядок роста будет постоянным , поскольку в лучшем случае мы предполагаем, что (n) четное.
# Средний случай: В этом случае мы предположим, что четные и нечетные события равновероятны, поэтому порядок роста будет линейным.
#
# * Худший случай: порядок роста будет линейным , поскольку в этом случае мы предполагаем, что (n) всегда нечетное.

# %%
# Here c is a constant
for i in range(1, c+1):
	# some O(1) expressions

	# This code is contributed by Pushpesh Raj.

# %% [markdown]
# ### Линейная временная сложность $O(n)$:
#
# Временная сложность цикла считается O(n), если переменные цикла увеличиваются/уменьшаются на постоянную величину.
#
# Линейная временная сложность, обозначаемая как O(n), является мерой роста времени выполнения алгоритма пропорционально размеру входных данных. В алгоритме O(n) время выполнения увеличивается линейно с размером входных данных.
#
# **Например**, поиск элемента в несортированном массиве или итерация по массиву и выполнение постоянного объема работы для каждого элемента будет O(n) операций. Проще говоря, для входных данных размера n алгоритму требуется n шагов для завершения операции.

# %%
# Here c is a positive integer constant
for i in range(1, n+1, c):
	# some O(1) expressions

for i in range(n, 0, -c):
	# some O(1) expressions

	# This code is contributed by Pushpesh Raj

# %% [markdown]
# ### Квадратичная временная сложность $O(n^c)$:
# Временная сложность определяется как алгоритм, производительность которого прямо пропорциональна квадрату размера входных данных, так как во вложенных циклах она равна количеству раз, которое выполняется самый внутренний оператор. Например, следующие циклы-образцы имеют временную сложность $O(n^2)$
#
# Квадратичная временная сложность, обозначаемая как $O(n^2)$, относится к алгоритму, время выполнения которого увеличивается пропорционально квадрату размера ввода. Другими словами, для ввода размера n алгоритму требуется n * n шагов для завершения операции.
#
# **Примером** алгоритма $O(n^2)$ является вложенный цикл, который итерирует по всему вводу для каждого элемента, выполняя постоянный объем работы для каждой итерации. Это приводит к общему количеству итераций n * n, что делает время выполнения квадратичным по размеру ввода.

# %%
for i in range(1, n+1, c):
	for j in range(1, n+1, c):
		# some O(1) expressions

for i in range(n, 0, -c):
	for j in range(i+1, n+1, c):
		# some O(1) expressions

		# This code is contributed by Pushpesh Raj

# %% [markdown]
# **Пример**: Сортировка выбором и сортировка вставкой имеют временную сложность $O(n^2)$.

# %% [markdown]
# ### Логарифмическая временная сложность $O(Log N)$:
# Временная сложность цикла считается как $O(Logn)$, если переменные цикла делятся/умножаются на постоянную величину. А также для рекурсивных вызовов в рекурсивной функции временная сложность считается как $O(Logn)$.

# %%
i = 1
while(i <= n):
	# some O(1) expressions
	i = i*c

i = n
while(i > 0):
	# some O(1) expressions
	i = i//c

# This code is contributed by Pushpesh Raj

# %%
# Recursive function
def recurse(n):
	if(n <= 0):
		return
	else:
		# some O(1) expressions
	recurse(n/c)
# Here c is positive integer constant greater than 1
# This code is contributed by Pushpesh Raj

# %% [markdown]
# **Пример**: двоичный поиск имеет временную сложность $O(Logn)$

# %% [markdown]
# ### Логарифмическая временная сложность $O(Log(LogN))$:
# Временная сложность цикла считается равной $O(Log(Logn))$, если переменные цикла уменьшаются/увеличиваются экспоненциально на постоянную величину.

# %%
# Here c is a constant greater than 1
i = 2
while(i <= n):
	# some O(1) expressions
	i = i**c

# Here fun is sqrt or cuberoot or any other constant root
i = n
while(i > 1):
	# some O(1) expressions
	i = fun(i)

# This code is contributed by Pushpesh Raj

# %% [markdown]
# **Как объединить временные сложности последовательных циклов?**
#
# При наличии последовательных циклов мы рассчитываем временную сложность как сумму временных сложностей отдельных циклов.
#
# Чтобы объединить временные сложности последовательных циклов, необходимо учесть количество итераций, выполняемых каждым циклом, и объем работы, выполняемой в каждой итерации. Общую временную сложность алгоритма можно рассчитать, умножив количество итераций каждого цикла на временную сложность каждой итерации и взяв максимум из всех возможных комбинаций.
#
# Например, рассмотрим следующий код:

# %%
for i in range(n):
  for j in range(m):
    # some constant time operation

# %% [markdown]
# Здесь внешний цикл выполняет n итераций, а внутренний цикл выполняет m итераций для каждой итерации внешнего цикла. Таким образом, общее количество итераций, выполняемых внутренним циклом, равно n * m, а общая временная сложность равна O(n * m).
#
# В другом примере рассмотрим следующий код:

# %%
for i in range(n):
  for j in range(i):
    # some constant time operation

# %% [markdown]
# Здесь внешний цикл выполняет n итераций, а внутренний цикл выполняет i итераций для каждой итерации внешнего цикла, где i — текущий счетчик итераций внешнего цикла. Общее количество итераций, выполненных внутренним циклом, можно вычислить, суммируя количество итераций, выполненных в каждой итерации внешнего цикла, которое определяется формулой sum(i) от i=1 до n, что равно n * (n + 1) / 2. Следовательно, общий временной комплекс

# %%
for i in range(1, m+1, c):
	# some O(1) expressions

for i in range(1, n+1, c):
	# some O(1) expressions


# Time complexity of above code is O(m) + O(n) which is O(m + n)
# If m == n, the time complexity becomes O(2n) which is O(n).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Хорошо про обозначения: https://www.geeksforgeeks.org/types-of-asymptotic-notations-in-complexity-analysis-of-algorithms/

# %% [markdown]
# Квиз: https://www.geeksforgeeks.org/quizzes/quiz-on-complexity-analysis-for-dsa/?page=1

# %% [markdown]
# Очень большой квиз: https://www.geeksforgeeks.org/quizzes/top-mcqs-on-complexity-analysis-of-algorithms-with-answers/

# %% [markdown]
# ![photo_2025-02-07_19-29-12.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Сортировки
#
# HOW TO: https://habr.com/ru/companies/kts/articles/727528/,

# %% [markdown]
# ### Heap (куча)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  https://pythonist.ru/algoritmy-sortirovki-s-python/?ysclid=m6uzldhwg2149764276 -- Heapsort

# %% [markdown]
# КВИЗ: https://www.geeksforgeeks.org/quizzes/top-mcqs-on-sorting-algorithms-with-answers/

# %% [markdown]
# Types of Algorithms:
#
# * Brute Force Algorithm
#
# * Recursive Algorithm
#
# * Backtracking Algorithm
#
# * Searching Algorithm
#
# * Sorting Algorithm
#
# * Hashing Algorithm
#
# * Divide and Conquer Algorithm
#
# * Greedy Algorithm
#
# * Dynamic Programming Algorithm
#
# * Randomized Algorithm

# %% [markdown]
# ## Backtracking Algorithm

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Бэктрекинг** — это алгоритмический метод решения проблем, который включает в себя поиск решения постепенно, пробуя различные варианты и отменяя их, если они ведут в тупик. Он обычно используется в ситуациях, когда вам нужно исследовать несколько возможностей для решения проблемы, например, искать путь в лабиринте или решать головоломки, такие как судоку. Когда тупик достигнут, алгоритм возвращается к предыдущей точке принятия решения и исследует другой путь до тех пор, пока не будет найдено решение или не будут исчерпаны все возможности.
#
# ### **Основная терминология**
# * **Кандидат**: Кандидат — это потенциальный выбор или элемент, который может быть добавлен к текущему решению.
#
# * **Решение**: Решение представляет собой действительную и полную конфигурацию, удовлетворяющую всем ограничениям проблемы.
#
# * **Частичное решение**: Частичное решение — это промежуточная или неполная конфигурация, создаваемая в процессе возврата.
#
# * **Пространство принятия решений**: Пространство принятия решений — это набор всех возможных кандидатов или вариантов в каждой точке принятия решения.
#
# * **Точка принятия решения**: Точка принятия решения — это определенный шаг в алгоритме, на котором кандидат выбирается и добавляется к частичному решению.
#
# * **Осуществимое решение**: Осуществимое решение — это частичное или полное решение, которое соответствует всем ограничениям.
#
# * **Тупик (Dead End)**: Тупик возникает, когда частичное решение не может быть расширено без нарушения ограничений.
#
# * **Backtrack**: Возврат включает в себя отмену предыдущих решений и возврат к предыдущей точке принятия решения.
#
# * **Пространство поиска**: Пространство поиска включает в себя все возможные комбинации кандидатов и вариантов.
#
# * **Оптимальное решение**: В задачах оптимизации оптимальное решение является наилучшим возможным решением.
#
# ### Типы проблем с бэктрекингом:
# * Проблема принятия решений: Здесь мы ищем осуществимое решение.
#
# * Проблема оптимизации: Для этого типа мы ищем лучшее решение.
#
# * Задачи перечисления: Мы находим множество всех возможных возможных решений задач этого типа.
#
# ### Как работает функция Backtracking?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Как показано на рисунке, « IS» представляет начальное состояние , в котором рекурсивный вызов начинает поиск допустимого решения.
#
# * C: он представляет различные контрольные точки для рекурсивных вызовов.
#
#
# * TN : представляет собой конечные узлы , в которых не могут быть выполнены никакие дальнейшие рекурсивные вызовы; эти узлы выступают в качестве базового случая рекурсии, и мы определяем, является ли текущее решение допустимым или нет в этом состоянии.
#
#
# * На каждой контрольной точке наша программа принимает некоторые решения и переходит к другим контрольным точкам, пока не достигнет конечного узла, после определения того, является ли решение допустимым или нет, программа начинает возвращаться к контрольным точкам и пытаться исследовать другие пути. Например, на изображении выше TN1…TN5 — это конечный узел, где решение неприемлемо, в то время как TN6 — это состояние, в котором мы нашли допустимое решение.
#
#
# * Стрелки назад на изображениях показывают возврат к предыдущим действиям, когда мы отменяем изменения, внесенные в некоторую контрольную точку.

# %% [markdown]
# Чтобы понять, основана ли проблема на Backtracking или нет, давайте рассмотрим простую задачу:
#
# **Задача**: Представьте, что у вас есть 3 закрытых ящика, среди которых 2 пустых, а в 1 лежит золотая монета. Ваша задача — достать золотую монету.
#
#
# **Почему динамическое программирование не решает этот вопрос**:
# влияет ли открытие или закрытие одного ящика на другой ящик? Оказывается, НЕТ, каждый ящик независим друг от друга, и состояние открытия/закрытия одного ящика не может определить переход для других ящиков. Следовательно, DP терпит неудачу.
#
#
# **Почему жадный алгоритм не может решить этот вопрос**:
# Жадный алгоритм выбирает локальный максимум, чтобы получить глобальный максимум, но в этой задаче каждый ящик имеет одинаковую вероятность наличия золотой монеты, т. е. 1/3, поэтому нет критериев для жадного выбора.
#
#
# **Почему бэктрэгинг работает**:
# Как уже обсуждалось, алгоритм отката — это просто перебор всех вариантов, поэтому мы можем по одному выбирать каждую коробку, чтобы найти золотую монету. Если коробка окажется пустой, мы можем закрыть ее, что и является шагом отката.
#
#
# Технически, для задач обратного отслеживания:
#
#
# * Алгоритм строит решение, исследуя все возможные пути, созданные выбором в задаче, это решение начинается с пустого множества S={}
#
# * Каждый выбор создает новое поддерево « s» , которое мы добавляем в набор.
# Теперь существуют два случая:
#
#   S+s — допустимый набор
#
#   S+s не является допустимым набором
#
#
# Если набор действителен, то мы делаем дальнейший выбор и повторяем процесс до тех пор, пока не будет найдено решение, в противном случае мы отменяем наше решение о включении «s» и исследуем другие пути, пока не будет найдено решение или пока не будут исчерпаны все возможные пути.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Поскольку алгоритм обратного отслеживания является чисто грубым перебором, то с точки зрения временной сложности он работает очень плохо. Обычно можно увидеть, что возвратное отслеживание имеет следующие временные сложности:
#
# * Экспоненциальный (O(K^N))
# * Факториал (O(N!))

# %% [markdown]
# Эти сложности обусловлены тем, что в каждом состоянии у нас есть несколько вариантов выбора, из-за чего число путей увеличивается, а поддеревья быстро разрастаются.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Пример : Алгоритм решения судоку
# Дано неполное судоку в виде матрицы mat[][] порядка 9*9.
#
# * Каждая из цифр  1-9 должна встречаться ровно один раз в каждой строке.
# * Каждая из цифр  1-9 должна встречаться ровно один раз в каждом столбце.
# * Каждая из цифр  1-9 должна встречаться ровно один раз в каждом из 9  3x3 подполей сетки.
#
# **Примечание**: нули в mat[][] обозначают пробелы, которые необходимо заполнить числом от 1 до 9. Вы не можете заменить элемент в ячейке, которая не является пустой.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Идея состоит в том, чтобы использовать возврат и рекурсивно генерировать все возможные конфигурации чисел от 1 до 9 для заполнения пустых ячеек матрицы mat[][]. Для этого для каждой нераспределенной ячейки заполните ячейку числом от 1 до 9 по одному. После заполнения нераспределенной ячейки проверьте, безопасна ли матрица . Если безопасна, перейдите к следующей ячейке, иначе выполните возврат для других случаев.
#
#
# Чтобы проверить , безопасно ли помещать значение num в ячейку mat[i][j] , пройдитесь по всем столбцам строки i , строкам столбца j и матрице 3*3 , содержащей ячейку (i, j) , и проверьте , есть ли у них уже значение num , если да, верните false , в противном случае верните true .
#
# **Временная сложность**: O(n*9 (n*n) ), для каждого неназначенного индекса существует 9 возможных вариантов, и для каждого индекса мы проверяем другие столбцы, строки и поля.

# %%
# Python Program to solve Sudoku problem

# Function to check if it is safe to place num at mat[row][col]
def isSafe(mat, row, col, num):
    # Check if num exists in the row
    for x in range(9):
        if mat[row][x] == num:
            return False

    # Check if num exists in the col
    for x in range(9):
        if mat[x][col] == num:
            return False

    # Check if num exists in the 3x3 sub-matrix
    startRow = row - (row % 3)
    startCol = col - (col % 3)

    for i in range(3):
        for j in range(3):
            if mat[i + startRow][j + startCol] == num:
                return False

    return True

# Function to solve the Sudoku problem
def solveSudokuRec(mat, row, col):
    # base case: Reached nth column of the last row
    if row == 8 and col == 9:
        return True

    # If last column of the row go to the next row
    if col == 9:
        row += 1
        col = 0

    # If cell is already occupied then move forward
    if mat[row][col] != 0:
        return solveSudokuRec(mat, row, col + 1)

    for num in range(1, 10):
        # If it is safe to place num at current position
        if isSafe(mat, row, col, num):
            mat[row][col] = num
            if solveSudokuRec(mat, row, col + 1):
                return True
            mat[row][col] = 0

    return False

def solveSudoku(mat):
    solveSudokuRec(mat, 0, 0)

if __name__ == "__main__":
    mat = [
        [3, 0, 6, 5, 0, 8, 4, 0, 0],
        [5, 2, 0, 0, 0, 0, 0, 0, 0],
        [0, 8, 7, 0, 0, 0, 0, 3, 1],
        [0, 0, 3, 0, 1, 0, 0, 8, 0],
        [9, 0, 0, 8, 6, 3, 0, 0, 5],
        [0, 5, 0, 0, 9, 0, 6, 0, 0],
        [1, 3, 0, 0, 0, 0, 2, 5, 0],
        [0, 0, 0, 0, 0, 0, 0, 7, 4],
        [0, 0, 5, 2, 0, 6, 3, 0, 0]
    ]

    solveSudoku(mat)

    for row in mat:
        print(" ".join(map(str, row)))
